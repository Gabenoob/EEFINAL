# %%
# read matlab data
import scipy.io as sio
import numpy as np

data = sio.loadmat("/Users/gabe/Desktop/EEFINAL/Matrix_factorize/bounded-simplex-structured-matrix-factorization/datasets/mnist.mat")
data = data['X']
# save data
np.save('mnist.npy', data)

# %%
# process a picture
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

path = "data_new/dog.jpg"

data = plt.imread("data_new/dog.jpg")
plt.imshow(data)

# compress it into 500x500
data = data[::4, 0::4]
ori = data

# show it in grayscale
plt.imshow(data, cmap='gray')
ori.shape
# Out:
# (250, 250)

# %%
data
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
data_noise = data + np.random.normal(0, 10, size=data.shape)
data_noise = np.clip(data_noise, 0, 255)
plt.imshow(data_noise, cmap='gray')
data_noise
# Out:
# array([[255.        , 255.        , 253.71049048, ..., 243.99358758,
#         255.        , 239.29269531],
#        [242.82482837, 248.95238687, 255.        , ..., 255.        ,
#         255.        , 255.        ],
#        [255.        , 255.        , 255.        , ..., 255.        ,
#         250.36959029, 255.        ],
#        ...,
#        [244.41184332, 255.        , 255.        , ..., 255.        ,
#         255.        , 239.99635959],
#        [255.        , 255.        , 251.57558481, ..., 255.        ,
#         241.7232861 , 255.        ],
#        [253.47283947, 255.        , 242.64054392, ..., 255.        ,
#         244.73545367, 255.        ]])

# %%
random_data_noise = np.random.normal(0, 10, size=data.shape)
random_data_noise = np.clip(random_data_noise, 0, 255)
plt.imshow(random_data_noise, cmap='gray')

# %%
random_data_noise = np.random.normal(0, 10, size=data.shape)
random_data_noise
# Out:
# array([[ 11.2595741 ,   4.38653401, -17.62418152, ...,  -4.4710527 ,
#         -14.25751029,   3.53867152],
#        [  1.79274193,  -1.66048803, -10.60949789, ...,  -4.05293303,
#           6.46597057,   7.45312981],
#        [  1.69623532,  -4.2333883 ,  -8.12786007, ..., -21.44891083,
#          -0.60637102,   4.09167219],
#        ...,
#        [ -3.68961686,   0.22630382,  15.23223104, ...,  -1.56987105,
#          -1.98159488, -10.2098571 ],
#        [  0.80348312, -17.95562522,  -7.79262853, ...,  -0.1746879 ,
#          -6.00730061,  -1.11433471],
#        [  5.62776921,   8.50477961,   2.34354271, ...,  -6.94657841,
#         -10.16233235,  -4.12401771]])

# %%
X = []
noise = []
for i in range(3):
    data_noise = data.T + np.random.normal(0, 60, size=data.shape)
    data_noise = np.clip(data_noise, 0, 255)
    X.append(data_noise)
for i in range(3):
    random_data_noise = np.random.normal(0, 60, size=data.shape)
    random_data_noise = np.clip(random_data_noise, 0, 255)
    X.append(random_data_noise)
X = np.array(X)
X = X.reshape(X.shape[0], -1)
X = X.T
print(X.shape)

# save data
sio.savemat("data_new/dog.mat", {'X': X})
# Out:
# (62500, 6)

# %% [markdown]
# 降噪成功,应用场景
#
# 改变降维的维数造成的影响
#
# 分析算法性能:
#
# 1. m的变化对时间的影响：计算算法复杂度
#
# 2. n的变化对时间的影响：计算算法复杂度

# %%
# show the result after processing
data = sio.loadmat("data_new/output.mat")
Wb = data['Wb']

plt.imshow(Wb.reshape(500,500,2)[:,:,0].T*255, cmap='gray')
plt.title('First component')
# Out:
# Text(0.5, 1.0, 'First component')

# %%
plt.imshow(Wb.reshape(500,500,2)[:,:,1].T*255, cmap='gray')
plt.title('second component')
# Out:
# Text(0.5, 1.0, 'second component')

# %% [markdown]
# 23.2151
